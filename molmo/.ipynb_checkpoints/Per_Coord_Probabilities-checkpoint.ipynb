# %%
import sys
from pathlib import Path
from PIL import Image
import torch
from transformers import AutoModelForCausalLM, AutoProcessor, GenerationConfig

parent_dir = Path.cwd().parent
sys.path.append(str(parent_dir))

from molmo_utils import load_model, get_coordinates, refactor_coordinates_to_where_to_place
from utils import extract_all, visualize_points_on_image, plot_euclidean_bplot

# %%
model_name = 'allenai/Molmo-7B-D-0924'
model, processor = load_model(model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt_start = "You are the robot in the picture. Your task is to: "
prompt_1 = " To complete this task, do two things. 1. Find the relevant object and point to it. 2. If your task somehow includes moving or putting the object somewhere in the image point to that location."
prompt_end = " Your output format should be like this: (x1, y1), (x2, y2), with (x1, y1) beeing the coordinates of the object to move and (x2, y2) the place to move it to. Dont output anything else."

# %%
def get_output(image_path, prompt, model, processor, temperature=0.2):
    with Image.open(image_path) as image:
        inputs = processor.process(
            images=image,
            text=prompt
        )
        inputs = {k: v.to(model.device).unsqueeze(0) for k, v in inputs.items()}
        with torch.autocast(device_type="cuda", enabled=True, dtype=torch.bfloat16):
                # Generate output
                output = model.generate_from_batch(
                    inputs,
                    GenerationConfig(max_new_tokens=200, stop_strings="<|endoftext|>", temperature=temperature, do_sample=True),
                    tokenizer=processor.tokenizer,
                    return_dict_in_generate=True,
                    output_logits=True
                )
        return output, inputs

def get_indeces_of_coords(generated_tokens, processor, inputs):
    index_of_coords = []
    for i, token in enumerate(reversed(generated_tokens)):
        char = processor.tokenizer.decode(token, skip_special_tokens=True)
        if ("(" in char) or (")" in char):
            index_of_coords.append(len(generated_tokens) - i - 1)
    return index_of_coords[::-1]

def get_logits(generated_logits, indeces):
    return generated_logits[indeces[0]:indeces[1]]

# %%
tasks, image_paths, ground_truths, _ = extract_all("../data/first_experiments")
softmax_fn = torch.nn.Softmax(dim=-1)

for i in range(len(tasks)):
    runs_with_two_coords = 0
    outputs = []
    image_path = image_paths[i]
    task = tasks[i]

    print(f"Task: {task}")
    print("")
    with Image.open(image_path) as image:
        image_width = image.width
        image_height = image.height
    for j in range(5):
        
        # Probability for two Coordinates alone
        prompt_start = "You are the robot in the picture. Your task is to: "
        prompt_1 = " To complete this task, do two things. 1. Find the relevant object and point to it. 2. If your task somehow includes moving or putting the object somewhere in the image point to that location."
        prompt_end = " Your output format should be like this: (x1, y1), (x2, y2), with (x1, y1) beeing the coordinates of the object to move and (x2, y2) the place to move it to. Dont output anything else."
        prompt = prompt_start + task + prompt_1 + prompt_end
        
        output, inputs = get_output(image_path, prompt, model, processor)
        logits = output.logits
        generated_logits = torch.cat(logits, dim=0)
        generated_tokens = output.sequences[0, inputs['input_ids'].size(1):]
        print(processor.tokenizer.decode(generated_tokens, skip_special_tokens=True))
        
        index_of_coords = get_indeces_of_coords(generated_tokens, processor, inputs)
        coord_1_logits = get_logits(generated_logits, index_of_coords[:2])
        coord_2_logits = get_logits(generated_logits, index_of_coords[2:4])
        
        logit_probs_1 = softmax_fn(coord_1_logits)
        highest_probs_1, _ = torch.max(logit_probs_1, dim=-1)
        output_probs_1 = torch.prod(highest_probs_1)

        logit_probs_2 = softmax_fn(coord_2_logits)
        highest_probs_2, _ = torch.max(logit_probs_2, dim=-1)
        output_probs_2 = torch.prod(highest_probs_2)


        # Probability for the first Coordinates alone
        prompt_start = "You are the robot in the picture. Your task is to: "
        prompt_1 = " To complete this task, do one thing. 1. Point to the location where the relevant object should be moved to."
        prompt_end = " Your output format should be like this: (x1, y1) with (x1, y1) beeing the coordinates of the object to move. Dont output anything else."
        prompt = prompt_start + task + prompt_1 + prompt_end
        
        output, inputs = get_output(image_path, prompt, model, processor)
        logits = output.logits
        generated_logits = torch.cat(logits, dim=0)
        generated_tokens = output.sequences[0, inputs['input_ids'].size(1):]
        print(processor.tokenizer.decode(generated_tokens, skip_special_tokens=True))
        
        index_of_coords = get_indeces_of_coords(generated_tokens, processor, inputs)
        coord_logits = get_logits(generated_logits, [index_of_coords[0], index_of_coords[-1]])

        logit_probs = softmax_fn(coord_logits)
        highest_probs, _ = torch.max(logit_probs, dim=-1)
        output_probs_object = torch.prod(highest_probs)


        # Probability for the second Coordinates alone
        prompt_start = "You are the robot in the picture. Your task is to: "
        prompt_1 = " To complete this task, do one thing. 1. Find the relevant object and point to it."
        prompt_end = " Your output format should be like this: (x1, y1) with (x1, y1) beeing the coordinates where the relevant object should be moved to. Dont output anything else."
        prompt = prompt_start + task + prompt_1 + prompt_end
        
        output, inputs = get_output(image_path, prompt, model, processor)
        logits = output.logits
        generated_logits = torch.cat(logits, dim=0)
        generated_tokens = output.sequences[0, inputs['input_ids'].size(1):]
        print(processor.tokenizer.decode(generated_tokens, skip_special_tokens=True))
        
        index_of_coords = get_indeces_of_coords(generated_tokens, processor, inputs)
        coord_logits = get_logits(generated_logits, [index_of_coords[0], index_of_coords[-1]])

        logit_probs = softmax_fn(coord_logits)
        highest_probs, _ = torch.max(logit_probs, dim=-1)
        output_probs_to_move = torch.prod(highest_probs)

        print("Prob if both together vs as single inferences:")
        print(f"Coordinate 1: {output_probs_1:.6f}, Coordinate 2: {output_probs_2:.6f}")
        print(f"Coordinate 1: {output_probs_object:.6f}, Coordinate 2: {output_probs_to_move:.6f}")

        print("")
# Out:
# Task: Move the can from the top left of the burner to the bottom left of the burner
#
#  (27.3, 25.5), (27.3, 50.0)
#  (24.0, 57.8)
#  (25.9, 58.2)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000850, Coordinate 2: 0.005949
# Coordinate 1: 0.000123, Coordinate 2: 0.000097
#
#  (27.4, 29.0), (27.4, 29.0)
#  (25.6, 58.4)
#  (25.4, 58.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000916, Coordinate 2: 0.039595
# Coordinate 1: 0.000102, Coordinate 2: 0.000081
#
#  (27.8, 25.4), (27.8, 43.3)
#  (25.3, 91.7)
#  (25.9, 57.4)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000835, Coordinate 2: 0.001683
# Coordinate 1: 0.000165, Coordinate 2: 0.000099
#
#  (27.5, 27.3), (27.5, 52.0)
#  (25.0, 50.0)
#  (25.2, 57.3)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.001104, Coordinate 2: 0.001935
# Coordinate 1: 0.000262, Coordinate 2: 0.000102
#
#  (27.5, 28.9), (28.2, 50.3)
#  (25.2, 58.0)
#  (25.8, 58.8)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000809, Coordinate 2: 0.000727
# Coordinate 1: 0.000125, Coordinate 2: 0.000092
#
# Task: pick up red srewdriver
#
#  (28.2, 32.9), (50.0, 50.0)
#  (50.0, 50.0)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000021, Coordinate 2: 0.005099
# Coordinate 1: 0.023867, Coordinate 2: 0.031305
#
#  (28.8, 30.2), (50.0, 50.0)
#  (50.0, 50.0)
#  (15.9, 29.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000026, Coordinate 2: 0.004885
# Coordinate 1: 0.023867, Coordinate 2: 0.000049
#
#  (28.7, 30.7), (50.0, 50.0)
#  (15.0, 30.1)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000024, Coordinate 2: 0.005850
# Coordinate 1: 0.000051, Coordinate 2: 0.031305
#
#  (29.6, 39.0), (50.0, 47.4)
#  (25.3, 42.9)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000027, Coordinate 2: 0.000076
# Coordinate 1: 0.000016, Coordinate 2: 0.031305
#
#  (49.1, 42.5), (50.0, 36.3)
#  (50.0, 50.0)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000025, Coordinate 2: 0.000046
# Coordinate 1: 0.023867, Coordinate 2: 0.031305
#
# Task: take the broccoli and put it between the two right burners
#
#  (45.4, 43.3), (58.0, 50.2)
#  (60.1, 50.6)
#  (60.0, 49.2)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000816, Coordinate 2: 0.000402
# Coordinate 1: 0.000105, Coordinate 2: 0.000145
#
#  (44.8, 42.2), (59.8, 50.8)
#  (60.1, 50.5)
#  (60.0, 48.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000792, Coordinate 2: 0.000550
# Coordinate 1: 0.000105, Coordinate 2: 0.000154
#
#  (44.6, 42.2), (58.5, 50.1)
#  (60.0, 53.0)
#  (61.5, 49.6)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000780, Coordinate 2: 0.000485
# Coordinate 1: 0.000135, Coordinate 2: 0.000101
#
#  (44.5, 42.0), (59.3, 46.8)
#  (60.1, 51.0)
#  (61.5, 48.3)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000745, Coordinate 2: 0.000305
# Coordinate 1: 0.000106, Coordinate 2: 0.000098
#
#  (45.0, 40.6), (60.0, 52.6)
#  (70.0, 58.3)
#  (60.0, 47.3)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000687, Coordinate 2: 0.000328
# Coordinate 1: 0.000202, Coordinate 2: 0.000142
#
# Task: move arch on the table and place it on top of another arch
#
#  (41.5, 73.3), (70.8, 76.6)
#  (50.0, 50.0)
#  (68.1, 76.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000125, Coordinate 2: 0.000090
# Coordinate 1: 0.024700, Coordinate 2: 0.000121
#
#  (41.9, 73.1), (69.6, 77.8)
#  (50.0, 50.0)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000127, Coordinate 2: 0.000173
# Coordinate 1: 0.024700, Coordinate 2: 0.018090
#
#  (40.8, 73.3), (42.4, 62.2)
#  (50.0, 50.0)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000106, Coordinate 2: 0.000091
# Coordinate 1: 0.024700, Coordinate 2: 0.018090
#
#  (41.0, 73.2), (69.7, 77.5)
#  (50.0, 50.0)
#  (70.1, 76.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000129, Coordinate 2: 0.000164
# Coordinate 1: 0.024700, Coordinate 2: 0.000141
#
#  (41.4, 72.9), (70.8, 75.6)
#  (50.0, 50.0)
#  (55.8, 71.4)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000118, Coordinate 2: 0.000096
# Coordinate 1: 0.024700, Coordinate 2: 0.000029
#
# Task: take sushi out of pan
#
#  (32.8, 22.2), (37.9, 59.3)
#  (60.2, 38.5)
#  (29.5, 24.6)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000543, Coordinate 2: 0.000114
# Coordinate 1: 0.000019, Coordinate 2: 0.000288
#
#  (32.2, 23.3), (37.8, 59.0)
#  (50.0, 50.0)
#  (32.6, 24.4)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000643, Coordinate 2: 0.000137
# Coordinate 1: 0.011985, Coordinate 2: 0.000146
#
#  (29.6, 23.0), (39.1, 59.0)
#  (-2.0, 1.5)
#  (29.6, 22.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.001542, Coordinate 2: 0.000118
# Coordinate 1: 0.000110, Coordinate 2: 0.000240
#
#  (31.0, 23.0), (41.5, 58.5)
#  (40.0, 45.0)
#  (29.5, 22.9)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000738, Coordinate 2: 0.000141
# Coordinate 1: 0.000099, Coordinate 2: 0.000234
#
#  (32.6, 23.5), (34.2, 20.3)
#  (10.0, 10.0)
#  (29.7, 23.1)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000690, Coordinate 2: 0.000061
# Coordinate 1: 0.001865, Coordinate 2: 0.000264
#
# Task: pick up glass cup
#
#  (38.1, 62.0), (50.0, 42.0)
#  (50.0, 50.0)
#  (50.0, 50.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000139, Coordinate 2: 0.000399
# Coordinate 1: 0.008503, Coordinate 2: 0.010357
#
#  (37.0, 59.5), (51.0, 39.5)
#  (50.0, 45.6)
#  (50.0, 40.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000238, Coordinate 2: 0.000238
# Coordinate 1: 0.000815, Coordinate 2: 0.000642
#
#  (40.2, 59.6), (53.0, 39.6)
#  (10.0, 10.0)
#  (50.0, 45.6)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000184, Coordinate 2: 0.000194
# Coordinate 1: 0.004583, Coordinate 2: 0.000863
#
#  (41.1, 60.7), (50.2, 39.0)
#  (50.0, 45.6)
#  (51.9, 41.6)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000145, Coordinate 2: 0.000265
# Coordinate 1: 0.000815, Coordinate 2: 0.000095
#
#  (41.3, 61.4), (51.5, 38.7)
#  (50.0, 45.6)
#  (54.4, 44.4)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000150, Coordinate 2: 0.000203
# Coordinate 1: 0.000815, Coordinate 2: 0.000077
#
# Task: open low fridge
#
#  (59.6, 63.8), (59.6, 81.2)
#  (49.9, 54.2)
#  (49.9, 66.9)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000108, Coordinate 2: 0.000660
# Coordinate 1: 0.000058, Coordinate 2: 0.000109
#
#  (59.4, 63.3), (59.4, 63.3)
#  (48.2, 52.8)
#  (49.8, 74.8)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000101, Coordinate 2: 0.008767
# Coordinate 1: 0.000034, Coordinate 2: 0.000205
#
#  (58.2, 60.4), (58.2, 60.4)
#  (49.9, 60.5)
#  (59.8, 57.9)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000085, Coordinate 2: 0.004546
# Coordinate 1: 0.000074, Coordinate 2: 0.000119
#
#  (59.0, 58.5), (59.0, 58.5)
#  (49.9, 53.8)
#  (49.9, 64.0)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000122, Coordinate 2: 0.012972
# Coordinate 1: 0.000066, Coordinate 2: 0.000131
#
#  (58.4, 60.8), (58.4, 76.3)
#  (49.9, 50.0)
#  (59.8, 61.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000086, Coordinate 2: 0.000337
# Coordinate 1: 0.000113, Coordinate 2: 0.000106
#
# Task: Place the pot to the right of the blue fork.
#
#  (45.2, 32.5), (60.5, 34.6)
#  (35.7, 62.1)
#  (42.7, 59.7)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000461, Coordinate 2: 0.000110
# Coordinate 1: 0.000052, Coordinate 2: 0.000051
#
#  (45.6, 31.8), (60.0, 34.0)
#  (35.4, 62.3)
#  (40.5, 40.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000415, Coordinate 2: 0.000101
# Coordinate 1: 0.000052, Coordinate 2: 0.000149
#
#  (44.8, 31.5), (55.8, 33.4)
#  (30.5, 60.1)
#  (40.6, 59.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000479, Coordinate 2: 0.000048
# Coordinate 1: 0.000110, Coordinate 2: 0.000043
#
#  (45.0, 31.4), (60.0, 35.5)
#  (39.1, 59.9)
#  (40.6, 40.6)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000499, Coordinate 2: 0.000140
# Coordinate 1: 0.000038, Coordinate 2: 0.000129
#
#  (45.2, 32.3), (60.0, 35.9)
#  (35.8, 60.0)
#  (40.5, 58.5)
# Prob if both together vs as single inferences:
# Coordinate 1: 0.000461, Coordinate 2: 0.000124
# Coordinate 1: 0.000054, Coordinate 2: 0.000038

# %%
prompt_start = "You are the robot in the picture. Your task is to: "
prompt_1 = " To complete this task, do one thing. 1. Find the relevant object and point to it.
prompt_end = " Your output format should be like this: (x1, y1) with (x1, y1) beeing the coordinates of the object to move. Dont output anything else."

# %%
for i in range(len(tasks)):
    runs_with_two_coords = 0
    outputs = []
    image_path = image_paths[i]
    task = tasks[i]
    prompt = prompt_start + task + prompt_1 + prompt_end

    print(f"Task: {task}")
    with Image.open(image_path) as image:
        image_width = image.width
        image_height = image.height
    for j in range(10):
        output, inputs = get_output(image_path, prompt, model, processor)
        logits = output.logits
        generated_logits = torch.cat(logits, dim=0)
        generated_tokens = output.sequences[0, inputs['input_ids'].size(1):]
        
        index_of_coords = get_indeces_of_coords(generated_tokens, processor, inputs)
        coord_logits = get_logits(generated_logits, [index_of_coords[0], index_of_coords[-1]])
        
        softmax_fn = torch.nn.Softmax(dim=-1)

        logit_probs = softmax_fn(coord_logits)
        highest_probs, _ = torch.max(logit_probs, dim=-1)
        output_probs = torch.prod(highest_probs)

        print(f"Coordinate 1: {output_probs_1}, Coordinate 2: {output_probs_2}")
